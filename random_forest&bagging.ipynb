# %% [markdown]
# <a href="https://colab.research.google.com/github/apurvak3/Machine_Learning/blob/main/random_forest%26bagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas matplotlib scikit-learn

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier , RandomForestClassifier
from sklearn.tree import plot_tree

# %%
X,y = make_classification(n_samples =200 , n_features=5 , n_redundant=0 , n_informative=5 , n_clusters_per_class =2)

# %%
df= pd.DataFrame(X , columns=['col1','col2','col3','col4','col5'])
df['target'] =y

# %%
df.head(5)
# Out:
#        col1      col2      col3      col4      col5  target
# 0 -1.130942 -1.373573 -0.227632  3.149837  3.082902       0
# 1 -3.010957  2.620285 -0.866441 -0.319728  2.043378       1
# 2 -1.435931 -0.061906  1.237873 -2.911872  3.079359       0
# 3 -2.392338 -4.239150 -0.272504 -1.588615  3.867716       0
# 4 -2.140065 -1.893435 -1.158170  2.428257  2.944710       0

# %%
df.shape
# Out:
# (200, 6)

# %%
bag = BaggingClassifier(max_features=2)
bag.fit(df.iloc[:,:-1],df.iloc[:,-1])

fig, ax = plt.subplots(figsize=(10, 10))
plot_tree(bag.estimators_[0], ax=ax, filled=True, feature_names=df.columns[:-1].tolist())
plt.show()

# %%
rf = RandomForestClassifier()
rf.fit(df.iloc[:,:-1],df.iloc[:,-1])
fig, ax = plt.subplots(figsize=(10, 10))
plot_tree(rf.estimators_[0], ax=ax, filled=True, feature_names=df.columns[:-1].tolist())
plt.show()
